# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect(
    host="db",
    database="nellchuuu",
    user="Nelly",
    password="Abanokova"
)
cur = conn.cursor()

cur.execute("""
CREATE TABLE IF NOT EXISTS customers (
    id SERIAL PRIMARY KEY,
    customer_name TEXT,
    age INT,
    city TEXT,
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
)
""")
conn.commit()

cur.execute("INSERT INTO customers (customer_name, age, city) VALUES ('Alice', 25, 'NY')")
cur.execute("INSERT INTO customers (customer_name, age, city) VALUES ('Bob', 30, 'LA')")
cur.execute("INSERT INTO customers (customer_name, age, city) VALUES ('Charlie', 22, 'Chicago')")
conn.commit()

df = pd.read_sql("SELECT * FROM customers", conn)
print(df)

cur.close()
conn.close()

# %%
import pandas as pd
import psycopg2
import numpy as np
